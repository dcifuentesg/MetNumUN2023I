# %% [markdown]
# **Python 101 for Data Science**

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/4b66fec02ed54f2198463011efe1555a

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Data Analysis with Python**

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/01158fcdab664baf93c78a34c4d9b99a

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Data Visualization with Python**

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/4cede4eefe664fcd9c3a7cf62a9f2ccd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Linkedin Profile**

# %% [markdown]
# https://www.linkedin.com/in/david-alejandro-cifuentes-gonzalez-a7b085250/

# %% [markdown]
# ![image.png](data:image/png;base64,...)
